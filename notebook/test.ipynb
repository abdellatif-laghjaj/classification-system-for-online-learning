# %%
import os
import cv2
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from ultralytics import YOLO

# --- 1. Data Loading and Feature Extraction ---

dataset_dir = 'Dataset'  # Replace with your dataset path
img_size = (128, 128) 

# Load YOLOv8 model 
model_yolo = YOLO('yolov8m.pt') 

def load_data(dir_path):
    """Loads images and labels from directory structure, cropping people with YOLO."""
    images = []
    labels = []
    class_names = sorted(os.listdir(dir_path))
    for i, class_name in enumerate(class_names):
        class_dir = os.path.join(dir_path, class_name)
        for img_name in os.listdir(class_dir):
            img_path = os.path.join(class_dir, img_name)

            # Load image
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 

            # Object Detection with YOLOv8
            results = model_yolo(img) 

            # Get bounding box coordinates of the person
            x1, y1, x2, y2 = 0, 0, 0, 0 # Initialize coordinates 
            for r in results:
                boxes = r.boxes.xyxy.tolist()  # Bounding boxes
                classes = r.boxes.cls.tolist()  # Class indices
                for box, cls in zip(boxes, classes):
                    if cls == 0:  # Assuming 'person' is class 0 
                        x1, y1, x2, y2 = map(int, box) 
                        break  # Assuming only one person per image 

            # Square Cropping
            if x1 == 0 and y1 == 0 and x2 == 0 and y2 == 0:
                print(f"Warning: Person not detected in {img_path}. Skipping image.")
                continue  # Skip to the next image

            center_x = (x1 + x2) // 2
            center_y = (y1 + y2) // 2
            crop_size = max(x2 - x1, y2 - y1)  # Size of the larger side

            crop_x1 = max(0, center_x - crop_size // 2)
            crop_y1 = max(0, center_y - crop_size // 2)
            crop_x2 = min(img.shape[1], crop_x1 + crop_size)
            crop_y2 = min(img.shape[0], crop_y1 + crop_size)

            cropped_img = img[crop_y1:crop_y2, crop_x1:crop_x2]

            # Resize cropped image to desired size
            cropped_img = cv2.resize(cropped_img, img_size)

            # --- Preprocessing for VGG16 ---
            cropped_img = image.img_to_array(cropped_img) # Convert to array
            cropped_img = preprocess_input(cropped_img) 
            images.append(cropped_img)
            labels.append(i) 
        print(f"{class_name} folder is finished \n---------------------------------------------------------------------------------------------------------------------------------------\n---------------------------------------------------------------------------------------------------------------------------------------")
    
    return np.array(images), np.array(labels), class_names

# %%
# Load data 
X, y, class_names = load_data(dataset_dir)
print(f"Number of images {len(X)}")
print(f"Number of labels {len(y)}")
# Out:
# 0: 384x640 1 person, 1 vase, 796.1ms
# Speed: 9.1ms preprocess, 796.1ms inference, 1519.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 867.0ms
# Speed: 8.0ms preprocess, 867.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 903.9ms
# Speed: 2.0ms preprocess, 903.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 889.4ms
# Speed: 2.0ms preprocess, 889.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 817.5ms
# Speed: 2.1ms preprocess, 817.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 873.1ms
# Speed: 2.0ms preprocess, 873.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 886.8ms
# Speed: 2.1ms preprocess, 886.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 856.3ms
# Speed: 2.0ms preprocess, 856.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 829.5ms
# Speed: 3.0ms preprocess, 829.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 808.1ms
# Speed: 2.0ms preprocess, 808.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 715.3ms
# Speed: 2.1ms preprocess, 715.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 829.2ms
# Speed: 2.0ms preprocess, 829.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 864.3ms
# Speed: 2.9ms preprocess, 864.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 778.9ms
# Speed: 3.0ms preprocess, 778.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 860.2ms
# Speed: 3.0ms preprocess, 860.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 873.1ms
# Speed: 3.0ms preprocess, 873.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 883.5ms
# Speed: 3.0ms preprocess, 883.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 815.5ms
# Speed: 2.9ms preprocess, 815.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 855.4ms
# Speed: 3.0ms preprocess, 855.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 851.6ms
# Speed: 2.0ms preprocess, 851.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 780.9ms
# Speed: 2.0ms preprocess, 780.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 743.0ms
# Speed: 2.0ms preprocess, 743.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 746.6ms
# Speed: 3.0ms preprocess, 746.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 723.6ms
# Speed: 2.0ms preprocess, 723.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 731.8ms
# Speed: 2.0ms preprocess, 731.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 792.3ms
# Speed: 2.0ms preprocess, 792.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 877.7ms
# Speed: 2.0ms preprocess, 877.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 887.0ms
# Speed: 2.9ms preprocess, 887.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 797.2ms
# Speed: 2.0ms preprocess, 797.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 761.3ms
# Speed: 2.9ms preprocess, 761.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 759.2ms
# Speed: 2.0ms preprocess, 759.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 772.1ms
# Speed: 2.0ms preprocess, 772.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 844.0ms
# Speed: 3.0ms preprocess, 844.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 868.3ms
# Speed: 2.0ms preprocess, 868.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 920.0ms
# Speed: 3.1ms preprocess, 920.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 926.9ms
# Speed: 4.0ms preprocess, 926.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 921.2ms
# Speed: 2.0ms preprocess, 921.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 922.6ms
# Speed: 3.0ms preprocess, 922.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 920.3ms
# Speed: 2.0ms preprocess, 920.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 918.9ms
# Speed: 2.0ms preprocess, 918.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 907.2ms
# Speed: 2.0ms preprocess, 907.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 936.7ms
# Speed: 2.9ms preprocess, 936.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 916.9ms
# Speed: 2.0ms preprocess, 916.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 838.1ms
# Speed: 3.0ms preprocess, 838.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 827.7ms
# Speed: 3.1ms preprocess, 827.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 744.4ms
# Speed: 3.0ms preprocess, 744.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 752.0ms
# Speed: 3.0ms preprocess, 752.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 805.1ms
# Speed: 2.0ms preprocess, 805.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 880.6ms
# Speed: 2.0ms preprocess, 880.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 834.0ms
# Speed: 1.9ms preprocess, 834.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 810.2ms
# Speed: 3.0ms preprocess, 810.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 779.5ms
# Speed: 2.0ms preprocess, 779.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 793.1ms
# Speed: 1.9ms preprocess, 793.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 853.2ms
# Speed: 2.0ms preprocess, 853.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 826.7ms
# Speed: 3.0ms preprocess, 826.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 858.7ms
# Speed: 2.0ms preprocess, 858.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 749.7ms
# Speed: 4.2ms preprocess, 749.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 831.2ms
# Speed: 3.5ms preprocess, 831.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 872.0ms
# Speed: 3.3ms preprocess, 872.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 844.5ms
# Speed: 2.0ms preprocess, 844.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 825.9ms
# Speed: 2.0ms preprocess, 825.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 794.9ms
# Speed: 2.0ms preprocess, 794.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 787.5ms
# Speed: 2.1ms preprocess, 787.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 821.2ms
# Speed: 1.9ms preprocess, 821.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 865.0ms
# Speed: 2.1ms preprocess, 865.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 879.9ms
# Speed: 2.0ms preprocess, 879.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 811.3ms
# Speed: 3.0ms preprocess, 811.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 785.8ms
# Speed: 3.0ms preprocess, 785.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 759.8ms
# Speed: 3.0ms preprocess, 759.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 810.7ms
# Speed: 3.0ms preprocess, 810.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 816.9ms
# Speed: 2.0ms preprocess, 816.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 859.9ms
# Speed: 2.0ms preprocess, 859.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 822.1ms
# Speed: 3.0ms preprocess, 822.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 842.1ms
# Speed: 2.0ms preprocess, 842.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 819.7ms
# Speed: 2.7ms preprocess, 819.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 824.1ms
# Speed: 2.1ms preprocess, 824.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 834.8ms
# Speed: 3.0ms preprocess, 834.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 844.7ms
# Speed: 2.0ms preprocess, 844.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 857.3ms
# Speed: 3.0ms preprocess, 857.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 873.2ms
# Speed: 2.0ms preprocess, 873.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 816.5ms
# Speed: 2.0ms preprocess, 816.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 755.9ms
# Speed: 3.0ms preprocess, 755.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 714.8ms
# Speed: 2.0ms preprocess, 714.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 819.6ms
# Speed: 3.0ms preprocess, 819.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 845.3ms
# Speed: 3.0ms preprocess, 845.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 806.0ms
# Speed: 3.0ms preprocess, 806.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 847.8ms
# Speed: 2.0ms preprocess, 847.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 747.7ms
# Speed: 3.1ms preprocess, 747.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 804.8ms
# Speed: 3.0ms preprocess, 804.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 795.4ms
# Speed: 4.0ms preprocess, 795.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 795.3ms
# Speed: 3.0ms preprocess, 795.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 785.2ms
# Speed: 5.0ms preprocess, 785.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 808.6ms
# Speed: 2.0ms preprocess, 808.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 802.7ms
# Speed: 3.0ms preprocess, 802.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 817.8ms
# Speed: 2.0ms preprocess, 817.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 791.1ms
# Speed: 2.0ms preprocess, 791.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 791.4ms
# Speed: 6.0ms preprocess, 791.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 795.0ms
# Speed: 4.0ms preprocess, 795.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 799.1ms
# Speed: 1.5ms preprocess, 799.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 799.4ms
# Speed: 2.0ms preprocess, 799.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 778.7ms
# Speed: 3.0ms preprocess, 778.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 802.1ms
# Speed: 2.0ms preprocess, 802.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 758.3ms
# Speed: 2.0ms preprocess, 758.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 783.4ms
# Speed: 3.0ms preprocess, 783.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 791.3ms
# Speed: 2.0ms preprocess, 791.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 811.1ms
# Speed: 2.0ms preprocess, 811.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 778.4ms
# Speed: 2.0ms preprocess, 778.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 827.0ms
# Speed: 3.0ms preprocess, 827.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 836.2ms
# Speed: 2.0ms preprocess, 836.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 841.0ms
# Speed: 2.1ms preprocess, 841.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 811.2ms
# Speed: 2.0ms preprocess, 811.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 812.1ms
# Speed: 3.0ms preprocess, 812.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 862.1ms
# Speed: 2.0ms preprocess, 862.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 847.9ms
# Speed: 2.0ms preprocess, 847.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 777.5ms
# Speed: 2.0ms preprocess, 777.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 787.0ms
# Speed: 1.5ms preprocess, 787.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 807.7ms
# Speed: 2.0ms preprocess, 807.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 855.2ms
# Speed: 2.0ms preprocess, 855.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 805.1ms
# Speed: 3.0ms preprocess, 805.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 714.1ms
# Speed: 2.0ms preprocess, 714.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 786.0ms
# Speed: 2.0ms preprocess, 786.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 821.2ms
# Speed: 3.0ms preprocess, 821.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 830.1ms
# Speed: 2.5ms preprocess, 830.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 788.6ms
# Speed: 3.0ms preprocess, 788.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 837.3ms
# Speed: 2.0ms preprocess, 837.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 832.1ms
# Speed: 3.0ms preprocess, 832.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 851.9ms
# Speed: 2.9ms preprocess, 851.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 856.3ms
# Speed: 3.0ms preprocess, 856.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 817.4ms
# Speed: 3.5ms preprocess, 817.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 838.7ms
# Speed: 3.0ms preprocess, 838.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 872.5ms
# Speed: 3.0ms preprocess, 872.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 859.6ms
# Speed: 3.0ms preprocess, 859.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 833.3ms
# Speed: 3.0ms preprocess, 833.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 799.5ms
# Speed: 2.0ms preprocess, 799.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 869.2ms
# Speed: 3.0ms preprocess, 869.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 791.9ms
# Speed: 4.0ms preprocess, 791.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 857.3ms
# Speed: 2.0ms preprocess, 857.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 819.9ms
# Speed: 1.9ms preprocess, 819.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 784.9ms
# Speed: 3.0ms preprocess, 784.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 754.1ms
# Speed: 4.0ms preprocess, 754.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 835.9ms
# Speed: 3.0ms preprocess, 835.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 798.2ms
# Speed: 2.0ms preprocess, 798.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 830.4ms
# Speed: 2.0ms preprocess, 830.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 805.5ms
# Speed: 2.9ms preprocess, 805.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 789.6ms
# Speed: 3.0ms preprocess, 789.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 886.6ms
# Speed: 2.0ms preprocess, 886.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 874.8ms
# Speed: 3.0ms preprocess, 874.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 886.9ms
# Speed: 3.0ms preprocess, 886.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 789.4ms
# Speed: 3.0ms preprocess, 789.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 778.7ms
# Speed: 3.5ms preprocess, 778.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 798.7ms
# Speed: 2.0ms preprocess, 798.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 781.6ms
# Speed: 3.0ms preprocess, 781.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 769.5ms
# Speed: 2.3ms preprocess, 769.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 765.4ms
# Speed: 1.9ms preprocess, 765.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 762.6ms
# Speed: 4.0ms preprocess, 762.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 752.1ms
# Speed: 3.0ms preprocess, 752.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 746.9ms
# Speed: 3.0ms preprocess, 746.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 782.1ms
# Speed: 2.0ms preprocess, 782.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 749.8ms
# Speed: 2.0ms preprocess, 749.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 769.2ms
# Speed: 3.0ms preprocess, 769.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 783.9ms
# Speed: 2.0ms preprocess, 783.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 806.6ms
# Speed: 2.0ms preprocess, 806.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 789.1ms
# Speed: 3.0ms preprocess, 789.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 772.4ms
# Speed: 1.9ms preprocess, 772.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 789.6ms
# Speed: 3.0ms preprocess, 789.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 803.0ms
# Speed: 2.0ms preprocess, 803.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 783.5ms
# Speed: 3.0ms preprocess, 783.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 833.0ms
# Speed: 2.0ms preprocess, 833.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 805.9ms
# Speed: 3.0ms preprocess, 805.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 807.4ms
# Speed: 3.0ms preprocess, 807.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 805.4ms
# Speed: 3.0ms preprocess, 805.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 799.0ms
# Speed: 3.0ms preprocess, 799.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 818.0ms
# Speed: 3.0ms preprocess, 818.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 845.1ms
# Speed: 2.0ms preprocess, 845.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 799.2ms
# Speed: 2.0ms preprocess, 799.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 769.8ms
# Speed: 3.0ms preprocess, 769.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 776.3ms
# Speed: 2.0ms preprocess, 776.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 818.6ms
# Speed: 1.9ms preprocess, 818.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 782.2ms
# Speed: 2.0ms preprocess, 782.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 798.0ms
# Speed: 2.9ms preprocess, 798.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 768.2ms
# Speed: 3.0ms preprocess, 768.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 786.3ms
# Speed: 2.0ms preprocess, 786.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 755.3ms
# Speed: 2.9ms preprocess, 755.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 798.4ms
# Speed: 3.0ms preprocess, 798.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 771.0ms
# Speed: 1.9ms preprocess, 771.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 782.0ms
# Speed: 1.9ms preprocess, 782.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 730.2ms
# Speed: 2.0ms preprocess, 730.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 752.5ms
# Speed: 3.0ms preprocess, 752.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 774.2ms
# Speed: 2.0ms preprocess, 774.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 765.0ms
# Speed: 2.0ms preprocess, 765.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 759.9ms
# Speed: 2.0ms preprocess, 759.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 764.3ms
# Speed: 2.0ms preprocess, 764.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 775.9ms
# Speed: 2.0ms preprocess, 775.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 742.3ms
# Speed: 3.0ms preprocess, 742.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 728.8ms
# Speed: 3.0ms preprocess, 728.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 769.0ms
# Speed: 2.5ms preprocess, 769.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 780.6ms
# Speed: 2.0ms preprocess, 780.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 801.0ms
# Speed: 2.0ms preprocess, 801.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 835.6ms
# Speed: 3.0ms preprocess, 835.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 786.6ms
# Speed: 1.9ms preprocess, 786.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 796.1ms
# Speed: 3.0ms preprocess, 796.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 817.5ms
# Speed: 3.0ms preprocess, 817.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 814.6ms
# Speed: 1.9ms preprocess, 814.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 776.6ms
# Speed: 3.0ms preprocess, 776.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 768.1ms
# Speed: 3.0ms preprocess, 768.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 804.6ms
# Speed: 2.0ms preprocess, 804.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 817.8ms
# Speed: 2.0ms preprocess, 817.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 795.6ms
# Speed: 2.9ms preprocess, 795.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 824.8ms
# Speed: 3.0ms preprocess, 824.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 839.6ms
# Speed: 2.0ms preprocess, 839.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 797.2ms
# Speed: 2.0ms preprocess, 797.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 804.8ms
# Speed: 3.0ms preprocess, 804.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 715.2ms
# Speed: 3.0ms preprocess, 715.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 806.5ms
# Speed: 1.9ms preprocess, 806.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 785.4ms
# Speed: 2.0ms preprocess, 785.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 792.8ms
# Speed: 3.0ms preprocess, 792.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 791.6ms
# Speed: 2.0ms preprocess, 791.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 818.8ms
# Speed: 2.0ms preprocess, 818.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 781.7ms
# Speed: 3.0ms preprocess, 781.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 802.3ms
# Speed: 2.0ms preprocess, 802.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 799.5ms
# Speed: 2.9ms preprocess, 799.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 789.5ms
# Speed: 2.0ms preprocess, 789.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 784.4ms
# Speed: 3.0ms preprocess, 784.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 770.7ms
# Speed: 2.0ms preprocess, 770.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 799.0ms
# Speed: 3.0ms preprocess, 799.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 780.9ms
# Speed: 2.0ms preprocess, 780.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 771.0ms
# Speed: 3.0ms preprocess, 771.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 794.9ms
# Speed: 2.9ms preprocess, 794.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 802.0ms
# Speed: 3.0ms preprocess, 802.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 801.9ms
# Speed: 2.0ms preprocess, 801.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 789.4ms
# Speed: 2.9ms preprocess, 789.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 721.8ms
# Speed: 4.0ms preprocess, 721.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 760.4ms
# Speed: 3.0ms preprocess, 760.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 762.9ms
# Speed: 2.0ms preprocess, 762.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 754.4ms
# Speed: 3.0ms preprocess, 754.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 830.3ms
# Speed: 3.0ms preprocess, 830.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 754.0ms
# Speed: 2.0ms preprocess, 754.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 811.6ms
# Speed: 2.0ms preprocess, 811.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 811.6ms
# Speed: 3.0ms preprocess, 811.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 817.7ms
# Speed: 2.4ms preprocess, 817.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 762.4ms
# Speed: 2.0ms preprocess, 762.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 802.2ms
# Speed: 3.1ms preprocess, 802.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 817.9ms
# Speed: 3.0ms preprocess, 817.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 807.0ms
# Speed: 3.0ms preprocess, 807.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 845.9ms
# Speed: 2.0ms preprocess, 845.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 817.0ms
# Speed: 5.0ms preprocess, 817.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 835.9ms
# Speed: 2.0ms preprocess, 835.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 874.9ms
# Speed: 2.0ms preprocess, 874.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 816.5ms
# Speed: 3.0ms preprocess, 816.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 793.8ms
# Speed: 4.0ms preprocess, 793.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 807.4ms
# Speed: 3.5ms preprocess, 807.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 911.4ms
# Speed: 3.0ms preprocess, 911.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 861.0ms
# Speed: 2.1ms preprocess, 861.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 801.9ms
# Speed: 1.9ms preprocess, 801.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 838.5ms
# Speed: 3.0ms preprocess, 838.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 873.5ms
# Speed: 3.0ms preprocess, 873.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 860.3ms
# Speed: 3.0ms preprocess, 860.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 829.3ms
# Speed: 2.0ms preprocess, 829.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 866.9ms
# Speed: 3.0ms preprocess, 866.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 889.7ms
# Speed: 2.0ms preprocess, 889.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 901.8ms
# Speed: 3.0ms preprocess, 901.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 857.3ms
# Speed: 3.0ms preprocess, 857.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 895.3ms
# Speed: 2.0ms preprocess, 895.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 871.8ms
# Speed: 3.0ms preprocess, 871.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 878.6ms
# Speed: 1.9ms preprocess, 878.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 802.2ms
# Speed: 2.9ms preprocess, 802.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 800.6ms
# Speed: 2.5ms preprocess, 800.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 717.9ms
# Speed: 3.0ms preprocess, 717.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 742.2ms
# Speed: 2.9ms preprocess, 742.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 787.5ms
# Speed: 3.0ms preprocess, 787.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 797.3ms
# Speed: 2.0ms preprocess, 797.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 864.6ms
# Speed: 3.0ms preprocess, 864.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 807.5ms
# Speed: 3.1ms preprocess, 807.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 819.3ms
# Speed: 3.0ms preprocess, 819.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 863.6ms
# Speed: 2.0ms preprocess, 863.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 910.2ms
# Speed: 2.0ms preprocess, 910.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 786.4ms
# Speed: 3.0ms preprocess, 786.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 799.1ms
# Speed: 2.0ms preprocess, 799.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 850.1ms
# Speed: 3.0ms preprocess, 850.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 845.7ms
# Speed: 3.0ms preprocess, 845.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 894.0ms
# Speed: 3.0ms preprocess, 894.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 812.2ms
# Speed: 2.0ms preprocess, 812.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 860.7ms
# Speed: 2.0ms preprocess, 860.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 754.5ms
# Speed: 3.0ms preprocess, 754.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 895.3ms
# Speed: 3.0ms preprocess, 895.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 913.2ms
# Speed: 1.9ms preprocess, 913.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 898.2ms
# Speed: 3.1ms preprocess, 898.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 906.7ms
# Speed: 3.0ms preprocess, 906.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 886.4ms
# Speed: 2.0ms preprocess, 886.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 876.9ms
# Speed: 3.0ms preprocess, 876.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 884.6ms
# Speed: 2.0ms preprocess, 884.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 861.1ms
# Speed: 2.9ms preprocess, 861.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 818.8ms
# Speed: 2.0ms preprocess, 818.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 836.6ms
# Speed: 3.0ms preprocess, 836.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 883.6ms
# Speed: 2.0ms preprocess, 883.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 827.6ms
# Speed: 2.0ms preprocess, 827.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 786.1ms
# Speed: 3.0ms preprocess, 786.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 851.8ms
# Speed: 2.0ms preprocess, 851.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 837.3ms
# Speed: 2.9ms preprocess, 837.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 859.2ms
# Speed: 4.0ms preprocess, 859.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 894.0ms
# Speed: 2.9ms preprocess, 894.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 889.3ms
# Speed: 2.1ms preprocess, 889.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 772.2ms
# Speed: 2.0ms preprocess, 772.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 757.5ms
# Speed: 3.0ms preprocess, 757.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 842.8ms
# Speed: 3.0ms preprocess, 842.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 892.1ms
# Speed: 3.0ms preprocess, 892.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 881.8ms
# Speed: 2.0ms preprocess, 881.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 796.2ms
# Speed: 2.0ms preprocess, 796.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 907.3ms
# Speed: 2.0ms preprocess, 907.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 894.6ms
# Speed: 2.0ms preprocess, 894.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 897.2ms
# Speed: 3.0ms preprocess, 897.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 863.6ms
# Speed: 2.0ms preprocess, 863.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 907.6ms
# Speed: 3.0ms preprocess, 907.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 894.7ms
# Speed: 2.0ms preprocess, 894.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 904.0ms
# Speed: 3.0ms preprocess, 904.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 911.5ms
# Speed: 2.0ms preprocess, 911.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 788.9ms
# Speed: 3.0ms preprocess, 788.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 835.5ms
# Speed: 2.0ms preprocess, 835.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 909.3ms
# Speed: 2.9ms preprocess, 909.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 886.1ms
# Speed: 2.0ms preprocess, 886.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 845.7ms
# Speed: 2.9ms preprocess, 845.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 859.2ms
# Speed: 2.0ms preprocess, 859.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 835.8ms
# Speed: 2.1ms preprocess, 835.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 803.4ms
# Speed: 3.0ms preprocess, 803.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 824.4ms
# Speed: 3.0ms preprocess, 824.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 788.5ms
# Speed: 2.0ms preprocess, 788.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 799.9ms
# Speed: 2.0ms preprocess, 799.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 885.1ms
# Speed: 4.1ms preprocess, 885.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 824.6ms
# Speed: 3.0ms preprocess, 824.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 883.5ms
# Speed: 2.0ms preprocess, 883.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 812.3ms
# Speed: 2.0ms preprocess, 812.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 799.5ms
# Speed: 2.0ms preprocess, 799.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 832.0ms
# Speed: 2.1ms preprocess, 832.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 870.2ms
# Speed: 2.9ms preprocess, 870.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 812.3ms
# Speed: 3.0ms preprocess, 812.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 855.9ms
# Speed: 2.0ms preprocess, 855.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 797.4ms
# Speed: 2.0ms preprocess, 797.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 786.3ms
# Speed: 3.0ms preprocess, 786.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 710.5ms
# Speed: 2.0ms preprocess, 710.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 805.1ms
# Speed: 2.0ms preprocess, 805.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 786.2ms
# Speed: 2.0ms preprocess, 786.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 847.1ms
# Speed: 3.0ms preprocess, 847.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 821.6ms
# Speed: 3.0ms preprocess, 821.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 839.6ms
# Speed: 2.0ms preprocess, 839.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 863.9ms
# Speed: 2.0ms preprocess, 863.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 841.1ms
# Speed: 3.0ms preprocess, 841.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 858.3ms
# Speed: 1.9ms preprocess, 858.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 829.2ms
# Speed: 3.0ms preprocess, 829.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bird, 1 vase, 875.1ms
# Speed: 2.0ms preprocess, 875.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 839.4ms
# Speed: 2.0ms preprocess, 839.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 820.8ms
# Speed: 2.0ms preprocess, 820.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 790.4ms
# Speed: 2.0ms preprocess, 790.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 745.4ms
# Speed: 2.0ms preprocess, 745.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 847.8ms
# ...
#
# 0: 480x640 1 person, 1 bottle, 1035.6ms
# Speed: 2.0ms preprocess, 1035.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 975.1ms
# Speed: 7.0ms preprocess, 975.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1008.1ms
# Speed: 3.0ms preprocess, 1008.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1150.2ms
# Speed: 2.1ms preprocess, 1150.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1019.8ms
# Speed: 2.0ms preprocess, 1019.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 2 beds, 1023.0ms
# Speed: 3.0ms preprocess, 1023.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 2 beds, 1009.2ms
# Speed: 2.0ms preprocess, 1009.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1 toothbrush, 1048.2ms
# Speed: 3.0ms preprocess, 1048.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1127.2ms
# Speed: 4.0ms preprocess, 1127.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 toothbrush, 1034.0ms
# Speed: 5.0ms preprocess, 1034.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1137.1ms
# Speed: 3.0ms preprocess, 1137.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 984.0ms
# Speed: 5.0ms preprocess, 984.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 986.8ms
# Speed: 3.0ms preprocess, 986.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 969.4ms
# Speed: 3.0ms preprocess, 969.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 964.7ms
# Speed: 3.0ms preprocess, 964.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 977.0ms
# Speed: 3.0ms preprocess, 977.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 994.3ms
# Speed: 2.9ms preprocess, 994.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1090.9ms
# Speed: 2.0ms preprocess, 1090.9ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1000.6ms
# Speed: 2.0ms preprocess, 1000.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1104.0ms
# Speed: 2.0ms preprocess, 1104.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1137.6ms
# Speed: 3.0ms preprocess, 1137.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1024.5ms
# Speed: 3.0ms preprocess, 1024.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 996.9ms
# Speed: 2.0ms preprocess, 996.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 967.9ms
# Speed: 3.0ms preprocess, 967.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 976.5ms
# Speed: 2.0ms preprocess, 976.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1071.6ms
# Speed: 3.0ms preprocess, 1071.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1033.0ms
# Speed: 2.0ms preprocess, 1033.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1151.2ms
# Speed: 3.0ms preprocess, 1151.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1111.2ms
# Speed: 5.0ms preprocess, 1111.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1029.0ms
# Speed: 2.0ms preprocess, 1029.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1015.4ms
# Speed: 2.0ms preprocess, 1015.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 toothbrush, 1095.8ms
# Speed: 2.0ms preprocess, 1095.8ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1009.4ms
# Speed: 6.0ms preprocess, 1009.4ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1042.7ms
# Speed: 2.0ms preprocess, 1042.7ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1011.8ms
# Speed: 3.0ms preprocess, 1011.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1127.3ms
# Speed: 4.0ms preprocess, 1127.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1010.8ms
# Speed: 2.0ms preprocess, 1010.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1051.1ms
# Speed: 3.0ms preprocess, 1051.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1151.2ms
# Speed: 3.0ms preprocess, 1151.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1006.8ms
# Speed: 2.0ms preprocess, 1006.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1011.7ms
# Speed: 2.5ms preprocess, 1011.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 953.0ms
# Speed: 2.0ms preprocess, 953.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 917.4ms
# Speed: 3.0ms preprocess, 917.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 2 beds, 994.0ms
# Speed: 2.0ms preprocess, 994.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1000.7ms
# Speed: 3.0ms preprocess, 1000.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1 bed, 1004.4ms
# Speed: 2.0ms preprocess, 1004.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1127.7ms
# Speed: 3.0ms preprocess, 1127.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1154.6ms
# Speed: 2.0ms preprocess, 1154.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1009.8ms
# Speed: 4.0ms preprocess, 1009.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1031.3ms
# Speed: 4.0ms preprocess, 1031.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1163.4ms
# Speed: 3.0ms preprocess, 1163.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 994.1ms
# Speed: 3.4ms preprocess, 994.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1044.1ms
# Speed: 2.0ms preprocess, 1044.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1023.4ms
# Speed: 2.0ms preprocess, 1023.4ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1131.6ms
# Speed: 4.0ms preprocess, 1131.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1033.8ms
# Speed: 2.0ms preprocess, 1033.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1026.1ms
# Speed: 4.0ms preprocess, 1026.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1011.9ms
# Speed: 3.0ms preprocess, 1011.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 989.4ms
# Speed: 2.0ms preprocess, 989.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1008.8ms
# Speed: 3.0ms preprocess, 1008.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1055.9ms
# Speed: 1.9ms preprocess, 1055.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1003.6ms
# Speed: 2.0ms preprocess, 1003.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1215.0ms
# Speed: 3.0ms preprocess, 1215.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1002.1ms
# Speed: 3.0ms preprocess, 1002.1ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1031.6ms
# Speed: 3.0ms preprocess, 1031.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1039.7ms
# Speed: 2.1ms preprocess, 1039.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1155.6ms
# Speed: 3.0ms preprocess, 1155.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1035.0ms
# Speed: 3.0ms preprocess, 1035.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 977.4ms
# Speed: 7.0ms preprocess, 977.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 982.3ms
# Speed: 2.0ms preprocess, 982.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1086.4ms
# Speed: 3.0ms preprocess, 1086.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1104.7ms
# Speed: 2.0ms preprocess, 1104.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1020.3ms
# Speed: 2.0ms preprocess, 1020.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1 toothbrush, 1082.0ms
# Speed: 4.0ms preprocess, 1082.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1 bed, 1 toothbrush, 1013.6ms
# Speed: 4.0ms preprocess, 1013.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1020.8ms
# Speed: 3.0ms preprocess, 1020.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1125.4ms
# Speed: 3.0ms preprocess, 1125.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1022.4ms
# Speed: 2.0ms preprocess, 1022.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1048.4ms
# Speed: 2.0ms preprocess, 1048.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1024.4ms
# Speed: 3.0ms preprocess, 1024.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1009.7ms
# Speed: 2.0ms preprocess, 1009.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1049.6ms
# Speed: 3.0ms preprocess, 1049.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1066.4ms
# Speed: 3.0ms preprocess, 1066.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1021.9ms
# Speed: 5.0ms preprocess, 1021.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1117.9ms
# Speed: 3.0ms preprocess, 1117.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1044.8ms
# Speed: 2.0ms preprocess, 1044.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1015.0ms
# Speed: 6.0ms preprocess, 1015.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1028.6ms
# Speed: 3.0ms preprocess, 1028.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1016.8ms
# Speed: 3.0ms preprocess, 1016.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1125.8ms
# Speed: 3.0ms preprocess, 1125.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1028.9ms
# Speed: 3.0ms preprocess, 1028.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1108.0ms
# Speed: 5.0ms preprocess, 1108.0ms inference, 13.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 990.5ms
# Speed: 6.0ms preprocess, 990.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1016.8ms
# Speed: 1.9ms preprocess, 1016.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 978.0ms
# Speed: 2.0ms preprocess, 978.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 957.6ms
# Speed: 3.1ms preprocess, 957.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1072.1ms
# Speed: 2.1ms preprocess, 1072.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1095.9ms
# Speed: 3.0ms preprocess, 1095.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1172.2ms
# Speed: 3.0ms preprocess, 1172.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 toothbrush, 1136.0ms
# Speed: 3.0ms preprocess, 1136.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1089.9ms
# Speed: 3.0ms preprocess, 1089.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1090.2ms
# Speed: 2.0ms preprocess, 1090.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 993.0ms
# Speed: 2.0ms preprocess, 993.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1169.3ms
# Speed: 2.0ms preprocess, 1169.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 993.6ms
# Speed: 5.0ms preprocess, 993.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1001.3ms
# Speed: 3.0ms preprocess, 1001.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1019.0ms
# Speed: 3.0ms preprocess, 1019.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 toothbrush, 1029.0ms
# Speed: 3.0ms preprocess, 1029.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1116.4ms
# Speed: 4.0ms preprocess, 1116.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1034.1ms
# Speed: 2.0ms preprocess, 1034.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# writing_reading folder is finished
# ---------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------------------------------
# Number of images 8083
# Number of labels 8083

# %%
# Load VGG16 model (without top)
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(img_size[0], img_size[1], 3)) 

# Extract features
features = base_model.predict(X) 
features = features.reshape(features.shape[0], -1)
# Out:
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 148s 581ms/step

# %%
from imblearn.combine import SMOTEENN

smote_enn = SMOTEENN(random_state=42)
X_balanced, y_balanced = smote_enn.fit_resample(features, y)

# %%
# --- 2. Data Splitting and Scaling ---

X_train, X_test, y_train, y_test = train_test_split(X_balanced, y_balanced, test_size=0.2, shuffle=True, random_state=42)

# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)

# %%
print(f"{X_train.shape}, {X_test.shape}")
# Out:
# (16004, 8192), (4002, 8192)

# %%
# --- 3. Model Training (SVM) ---

model = SVC(kernel='rbf', C=1.0, random_state=42) 
model.fit(X_train, y_train)

# --- 4. Model Evaluation ---

y_pred = model.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred, target_names=class_names)) 
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 1.0
#                   precision    recall  f1-score   support
#
#       distracted       1.00      1.00      1.00       545
#          fatigue       1.00      1.00      1.00       580
#          focused       1.00      1.00      1.00       587
#       raise_hand       1.00      1.00      1.00       577
#         sleeping       1.00      1.00      1.00       574
# using_smartphone       1.00      1.00      1.00       604
#  writing_reading       1.00      1.00      1.00       535
#
#         accuracy                           1.00      4002
#        macro avg       1.00      1.00      1.00      4002
#     weighted avg       1.00      1.00      1.00      4002
#
# [[545   0   0   0   0   0   0]
#  [  0 580   0   0   0   0   0]
#  [  0   0 587   0   0   0   0]
#  [  0   0   0 577   0   0   0]
#  [  0   0   0   0 574   0   0]
#  [  0   0   0   0   0 604   0]
#  [  0   0   0   0   0   0 535]]

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors=5)  # Choose a value for k
knn_model.fit(X_train, y_train) 

# ... (Evaluate the model)
y_pred_knn = knn_model.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred_knn))
print(classification_report(y_test, y_pred_knn, target_names=class_names)) 
print(confusion_matrix(y_test, y_pred_knn))
# Out:
# Accuracy: 1.0
#                   precision    recall  f1-score   support
#
#       distracted       1.00      1.00      1.00       545
#          fatigue       1.00      1.00      1.00       580
#          focused       1.00      1.00      1.00       587
#       raise_hand       1.00      1.00      1.00       577
#         sleeping       1.00      1.00      1.00       574
# using_smartphone       1.00      1.00      1.00       604
#  writing_reading       1.00      1.00      1.00       535
#
#         accuracy                           1.00      4002
#        macro avg       1.00      1.00      1.00      4002
#     weighted avg       1.00      1.00      1.00      4002
#
# [[545   0   0   0   0   0   0]
#  [  0 580   0   0   0   0   0]
#  [  0   0 587   0   0   0   0]
#  [  0   0   0 577   0   0   0]
#  [  0   0   0   0 574   0   0]
#  [  0   0   0   0   0 604   0]
#  [  0   0   0   0   0   0 535]]

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)
# ... (Evaluate the model)
y_pred_dt = dt_model.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred_dt))
print(classification_report(y_test, y_pred_dt, target_names=class_names)) 
print(confusion_matrix(y_test, y_pred_dt))
# Out:
# Accuracy: 0.9955022488755623
#                   precision    recall  f1-score   support
#
#       distracted       0.99      1.00      0.99       545
#          fatigue       1.00      1.00      1.00       580
#          focused       1.00      0.99      0.99       587
#       raise_hand       0.99      1.00      1.00       577
#         sleeping       1.00      0.99      1.00       574
# using_smartphone       1.00      1.00      1.00       604
#  writing_reading       0.99      1.00      1.00       535
#
#         accuracy                           1.00      4002
#        macro avg       1.00      1.00      1.00      4002
#     weighted avg       1.00      1.00      1.00      4002
#
# [[543   0   0   0   0   2   0]
#  [  0 579   0   0   0   0   1]
#  [  0   0 579   3   2   1   2]
#  [  0   0   1 575   0   0   1]
#  [  2   0   1   0 571   0   0]
#  [  2   0   0   0   0 602   0]
#  [  0   0   0   0   0   0 535]]

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)  # Adjust n_estimators as needed
rf_model.fit(X_train, y_train)
# ... (Evaluate the model)
y_pred_rf = rf_model.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf, target_names=class_names)) 
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# Accuracy: 1.0
#                   precision    recall  f1-score   support
#
#       distracted       1.00      1.00      1.00       545
#          fatigue       1.00      1.00      1.00       580
#          focused       1.00      1.00      1.00       587
#       raise_hand       1.00      1.00      1.00       577
#         sleeping       1.00      1.00      1.00       574
# using_smartphone       1.00      1.00      1.00       604
#  writing_reading       1.00      1.00      1.00       535
#
#         accuracy                           1.00      4002
#        macro avg       1.00      1.00      1.00      4002
#     weighted avg       1.00      1.00      1.00      4002
#
# [[545   0   0   0   0   0   0]
#  [  0 580   0   0   0   0   0]
#  [  0   0 587   0   0   0   0]
#  [  0   0   0 577   0   0   0]
#  [  0   0   0   0 574   0   0]
#  [  0   0   0   0   0 604   0]
#  [  0   0   0   0   0   0 535]]

# %%
from sklearn.linear_model import LogisticRegression
lr_model = LogisticRegression(random_state=42) 
lr_model.fit(X_train, y_train)
# ... (Evaluate the model)
y_pred_lr = lr_model.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred_lr))
print(classification_report(y_test, y_pred_lr, target_names=class_names)) 
print(confusion_matrix(y_test, y_pred_lr))
# Out:
# Accuracy: 1.0
#                   precision    recall  f1-score   support
#
#       distracted       1.00      1.00      1.00       545
#          fatigue       1.00      1.00      1.00       580
#          focused       1.00      1.00      1.00       587
#       raise_hand       1.00      1.00      1.00       577
#         sleeping       1.00      1.00      1.00       574
# using_smartphone       1.00      1.00      1.00       604
#  writing_reading       1.00      1.00      1.00       535
#
#         accuracy                           1.00      4002
#        macro avg       1.00      1.00      1.00      4002
#     weighted avg       1.00      1.00      1.00      4002
#
# [[545   0   0   0   0   0   0]
#  [  0 580   0   0   0   0   0]
#  [  0   0 587   0   0   0   0]
#  [  0   0   0 577   0   0   0]
#  [  0   0   0   0 574   0   0]
#  [  0   0   0   0   0 604   0]
#  [  0   0   0   0   0   0 535]]
# c:\Users\abdel\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# --- 5. Prediction on a New Image ---

def predict_image(image_path, model, class_names):
    """Predicts the class of a single image."""
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 

    # Object Detection with YOLOv8
    results = model_yolo(img) 

     # Get bounding box coordinates of the person
    x1, y1, x2, y2 = 0, 0, 0, 0 # Initialize coordinates 
    for r in results:
        boxes = r.boxes.xyxy.tolist()  # Bounding boxes
        classes = r.boxes.cls.tolist()  # Class indices
        for box, cls in zip(boxes, classes):
            if cls == 0:  # Assuming 'person' is class 0 
                x1, y1, x2, y2 = map(int, box) 
                break  # Assuming only one person per image 

    # Square Cropping 
    center_x = (x1 + x2) // 2
    center_y = (y1 + y2) // 2
    crop_size = max(x2 - x1, y2 - y1)  # Size of the larger side

    crop_x1 = max(0, center_x - crop_size // 2)
    crop_y1 = max(0, center_y - crop_size // 2)
    crop_x2 = min(img.shape[1], crop_x1 + crop_size)
    crop_y2 = min(img.shape[0], crop_y1 + crop_size)

    cropped_img = img[crop_y1:crop_y2, crop_x1:crop_x2]

    # Resize cropped image to desired size
    cropped_img = cv2.resize(cropped_img, img_size)
    # Preprocess for VGG16
    cropped_img = image.img_to_array(cropped_img) 
    cropped_img = preprocess_input(cropped_img)
    cropped_img = np.expand_dims(cropped_img, axis=0) 

    features = base_model.predict(cropped_img)
    features = features.reshape(features.shape[0], -1) 
    # features = scaler.transform(features)

    prediction = model.predict(features)[0]  
    predicted_class = class_names[prediction] 

    return predicted_class

new_image_path = 'uploads/away.jpg' # Replace with your image path
predicted_class = predict_image(new_image_path, lr_model, class_names)
print("Predicted Class:", predicted_class)
# Out:
# 0: 384x640 1 person, 825.2ms
# Speed: 3.0ms preprocess, 825.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Predicted Class: distracted

# %%
import joblib
joblib.dump(model, "svm_3.pkl") # kinda good
joblib.dump(knn_model, "knn_3.pkl") #dumb
joblib.dump(dt_model, "dt_3.pkl") # Very stupid
joblib.dump(lr_model, "lr_3.pkl") # good to be fair
joblib.dump(rf_model, "rf_3.pkl")
# Out:
# ['rf_3.pkl']
